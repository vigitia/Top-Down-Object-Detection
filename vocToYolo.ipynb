# %% [markdown]
# <a href="https://colab.research.google.com/github/vigitia/Top-Down-Object-Detection/blob/main/vocToYolo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import logging
logging.getLogger().setLevel(logging.CRITICAL)
# !pip install pylabel > /dev/null

# %%
from pylabel import importer

# %%
path_to_annotations = "/content/data"

dataset = importer.ImportVOC(path_to_annotations)
dataset.export.ExportToYoloV5()
# Out:
# ['training/dataset.yaml',
#  'training/labels/e47efe34-7087-11ed-b2e3-1b1b14efb1a9.txt',
#  'training/labels/cdcc6862-7086-11ed-b2e3-1b1b14efb1a9.txt',
#  'training/labels/e3b4c578-7088-11ed-b2e3-1b1b14efb1a9.txt',
#  'training/labels/d3e15690-7086-11ed-b2e3-1b1b14efb1a9.txt',
#  'training/labels/c5b8b7ee-708a-11ed-b2e3-1b1b14efb1a9.txt',
#  'training/labels/75477c34-7088-11ed-b2e3-1b1b14efb1a9.txt',
#  'training/labels/7cac2254-7088-11ed-b2e3-1b1b14efb1a9.txt',
#  'training/labels/8f50b978-7089-11ed-b2e3-1b1b14efb1a9.txt',
#  'training/labels/3cdcfc5c-7088-11ed-b2e3-1b1b14efb1a9.txt',
#  'training/labels/5af64724-7089-11ed-b2e3-1b1b14efb1a9.txt',
#  'training/labels/e9317f50-7088-11ed-b2e3-1b1b14efb1a9.txt',
#  'training/labels/5a832158-708a-11ed-b2e3-1b1b14efb1a9.txt',
#  'training/labels/d98ffcc0-7088-11ed-b2e3-1b1b14efb1a9.txt',
#  'training/labels/b450b8c4-7087-11ed-b2e3-1b1b14efb1a9.txt',
#  'training/labels/e302f7ca-7089-11ed-b2e3-1b1b14efb1a9.txt',
# ...

# %%
from google.colab import files

# %%
# !zip -r /content/yolo_labels.zip /content/training
# Out:
#   adding: content/training/ (stored 0%)
#   adding: content/training/labels/ (stored 0%)
#   adding: content/training/labels/0e2fd704-7087-11ed-b2e3-1b1b14efb1a9.txt (deflated 7%)
#   adding: content/training/labels/b450b8c4-7087-11ed-b2e3-1b1b14efb1a9.txt (deflated 7%)
#   adding: content/training/labels/9c56f226-708a-11ed-b2e3-1b1b14efb1a9.txt (deflated 7%)
#   adding: content/training/labels/8dac7960-7087-11ed-b2e3-1b1b14efb1a9.txt (deflated 7%)
#   adding: content/training/labels/729bc46e-7087-11ed-b2e3-1b1b14efb1a9.txt (deflated 13%)
#   adding: content/training/labels/dcd19ab4-7089-11ed-b2e3-1b1b14efb1a9.txt (deflated 7%)
#   adding: content/training/labels/1efe105c-708a-11ed-b2e3-1b1b14efb1a9.txt (deflated 7%)
#   adding: content/training/labels/3b004e56-7089-11ed-b2e3-1b1b14efb1a9.txt (deflated 7%)
#   adding: content/training/labels/8b804b4c-7089-11ed-b2e3-1b1b14efb1a9.txt (deflated 10%)
# ...

# %%
files.download('/content/yolo_labels.zip')
